# %% [markdown]
# # Assemble data for CIS-PD Curation

# %% [markdown]
# Task List

# %% [markdown]
# # Import packages

# %%
# import packages
import os
import pandas as pd
import numpy as np
import re
import pathlib

# import h5py #save hdf5 but pandas has a function...

# %% [markdown]
# # Functions

# %%
path = r'//FS2.smpp.local\RTO\CIS-PD Study\MJFF Curation\TaskAcc'
# filename = r'//FS2.smpp.local\RTO\CIS-PD MUSC\codelist.sas7bdat'
# data124 = pd.read_hdf(os.path.join(path,'updrs_124.h5'))

# %%
def extract_data(path):
    """Open each csv file, extract metadata from filename and first and last timestamps."""
#     locations = [locs for locs in os.listdir(path) if os.path.isdir(os.path.join(path, locs))]
    list = []

    for root, dirs, files in os.walk(path, topdown=True):
        for filenames in files:
            if filenames.endswith('.csv'):
                p = pathlib.Path(os.path.join(root, filenames))
                name = str(p.relative_to(path)).split("\\")[0]
    #             series = series.append(name)
                list.append([name])

    df = pd.DataFrame(list,columns=['subjid'])

# %% [markdown]
# # Test function - line by line

# %%
# df = pd.DataFrame(columns = 'subjid')
# series = pd.Series()
list = []

for root, dirs, files in os.walk(path, topdown=True):
    for filenames in files:
        if filenames.endswith('.csv'):
            p = pathlib.Path(os.path.join(root, filenames))
            name = str(p.relative_to(path)).split("\\")[0]
#             series = series.append(name)
            list.append([name])

# check session name
colnames = ['subjid', 'session', 'activity']
# list
df = pd.DataFrame(np.column_stack([list, list, list]),columns=colnames)
# df = pd.DataFrame({'subjid':list, 'session':list, 'activity':list})

# use list (has file names), open file and extract start and stop timestamps
# make 2 columns and add to df

# %%
df
# Out:
#                    subjid              session             activity
# 0        1003_0_Drnkg.csv     1003_0_Drnkg.csv     1003_0_Drnkg.csv
# 1         1003_0_Drwg.csv      1003_0_Drwg.csv      1003_0_Drwg.csv
# 2         1003_0_Fldg.csv      1003_0_Fldg.csv      1003_0_Fldg.csv
# 3         1003_0_FtnL.csv      1003_0_FtnL.csv      1003_0_FtnL.csv
# 4         1003_0_FtnR.csv      1003_0_FtnR.csv      1003_0_FtnR.csv
# 5       1003_0_NtsBts.csv    1003_0_NtsBts.csv    1003_0_NtsBts.csv
# 6         1003_0_RamL.csv      1003_0_RamL.csv      1003_0_RamL.csv
# 7         1003_0_RamR.csv      1003_0_RamR.csv      1003_0_RamR.csv
# 8      1003_0_Shaking.csv   1003_0_Shaking.csv   1003_0_Shaking.csv
# 9       1003_0_Sheets.csv    1003_0_Sheets.csv    1003_0_Sheets.csv
# 10       1003_0_Sitng.csv     1003_0_Sitng.csv     1003_0_Sitng.csv
# 11    1003_0_SitStand.csv  1003_0_SitStand.csv  1003_0_SitStand.csv
# 12       1003_0_Stndg.csv     1003_0_Stndg.csv     1003_0_Stndg.csv
# 13        1003_0_Typg.csv      1003_0_Typg.csv      1003_0_Typg.csv
# 14        1003_0_Wlkg.csv      1003_0_Wlkg.csv      1003_0_Wlkg.csv
# 15     1003_0_WlkgCnt.csv   1003_0_WlkgCnt.csv   1003_0_WlkgCnt.csv
# 16       1003_1_Drnkg.csv     1003_1_Drnkg.csv     1003_1_Drnkg.csv
# 17        1003_1_Drwg.csv      1003_1_Drwg.csv      1003_1_Drwg.csv
# 18        1003_1_Fldg.csv      1003_1_Fldg.csv      1003_1_Fldg.csv
# 19        1003_1_FtnL.csv      1003_1_FtnL.csv      1003_1_FtnL.csv
# 20        1003_1_FtnR.csv      1003_1_FtnR.csv      1003_1_FtnR.csv
# 21      1003_1_NtsBts.csv    1003_1_NtsBts.csv    1003_1_NtsBts.csv
# 22        1003_1_RamL.csv      1003_1_RamL.csv      1003_1_RamL.csv
# 23        1003_1_RamR.csv      1003_1_RamR.csv      1003_1_RamR.csv
# 24      1003_1_Sheets.csv    1003_1_Sheets.csv    1003_1_Sheets.csv
# 25       1003_1_Sitng.csv     1003_1_Sitng.csv     1003_1_Sitng.csv
# 26    1003_1_SitStand.csv  1003_1_SitStand.csv  1003_1_SitStand.csv
# 27       1003_1_Stndg.csv     1003_1_Stndg.csv     1003_1_Stndg.csv
# 28        1003_1_Typg.csv      1003_1_Typg.csv      1003_1_Typg.csv
# 29        1003_1_Wlkg.csv      1003_1_Wlkg.csv      1003_1_Wlkg.csv
# ...                   ...                  ...                  ...
# 2087      1051_5_Fldg.csv      1051_5_Fldg.csv      1051_5_Fldg.csv
# 2088      1051_5_FtnL.csv      1051_5_FtnL.csv      1051_5_FtnL.csv
# 2089      1051_5_FtnR.csv      1051_5_FtnR.csv      1051_5_FtnR.csv
# 2090    1051_5_NtsBts.csv    1051_5_NtsBts.csv    1051_5_NtsBts.csv
# 2091      1051_5_RamL.csv      1051_5_RamL.csv      1051_5_RamL.csv
# 2092      1051_5_RamR.csv      1051_5_RamR.csv      1051_5_RamR.csv
# 2093   1051_5_Shaking.csv   1051_5_Shaking.csv   1051_5_Shaking.csv
# 2094    1051_5_Sheets.csv    1051_5_Sheets.csv    1051_5_Sheets.csv
# 2095     1051_5_Sitng.csv     1051_5_Sitng.csv     1051_5_Sitng.csv
# 2096  1051_5_SitStand.csv  1051_5_SitStand.csv  1051_5_SitStand.csv
# 2097     1051_5_Stndg.csv     1051_5_Stndg.csv     1051_5_Stndg.csv
# 2098      1051_5_Typg.csv      1051_5_Typg.csv      1051_5_Typg.csv
# 2099      1051_5_Wlkg.csv      1051_5_Wlkg.csv      1051_5_Wlkg.csv
# 2100   1051_5_WlkgCnt.csv   1051_5_WlkgCnt.csv   1051_5_WlkgCnt.csv
# 2101     1051_6_Drnkg.csv     1051_6_Drnkg.csv     1051_6_Drnkg.csv
# 2102      1051_6_Drwg.csv      1051_6_Drwg.csv      1051_6_Drwg.csv
# 2103      1051_6_Fldg.csv      1051_6_Fldg.csv      1051_6_Fldg.csv
# 2104      1051_6_FtnL.csv      1051_6_FtnL.csv      1051_6_FtnL.csv
# 2105      1051_6_FtnR.csv      1051_6_FtnR.csv      1051_6_FtnR.csv
# 2106    1051_6_NtsBts.csv    1051_6_NtsBts.csv    1051_6_NtsBts.csv
# 2107      1051_6_RamL.csv      1051_6_RamL.csv      1051_6_RamL.csv
# 2108      1051_6_RamR.csv      1051_6_RamR.csv      1051_6_RamR.csv
# 2109   1051_6_Shaking.csv   1051_6_Shaking.csv   1051_6_Shaking.csv
# 2110    1051_6_Sheets.csv    1051_6_Sheets.csv    1051_6_Sheets.csv
# 2111     1051_6_Sitng.csv     1051_6_Sitng.csv     1051_6_Sitng.csv
# 2112  1051_6_SitStand.csv  1051_6_SitStand.csv  1051_6_SitStand.csv
# 2113     1051_6_Stndg.csv     1051_6_Stndg.csv     1051_6_Stndg.csv
# 2114      1051_6_Typg.csv      1051_6_Typg.csv      1051_6_Typg.csv
# 2115      1051_6_Wlkg.csv      1051_6_Wlkg.csv      1051_6_Wlkg.csv
# 2116   1051_6_WlkgCnt.csv   1051_6_WlkgCnt.csv   1051_6_WlkgCnt.csv
#
# [2117 rows x 3 columns]

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #
